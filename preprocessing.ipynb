# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import LabelEncoder

# %%
# Load the data
file_path = Path("Resources\healthcare-dataset-stroke-data.csv")
df = pd.read_csv(file_path)
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
# Evaluate Data: Data types and null values
print(df.dtypes)

print(df.count())
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object
# id                   5110
# gender               5110
# age                  5110
# hypertension         5110
# heart_disease        5110
# ever_married         5110
# work_type            5110
# Residence_type       5110
# avg_glucose_level    5110
# bmi                  4909
# smoking_status       5110
# stroke               5110
# dtype: int64

# %%
# Drop rows if missing value
df = df.dropna(axis=0, inplace=False)
print(df.count())

# Drop Patient ID
df = df.drop(columns=['id'])
# Out:
# id                   4909
# gender               4909
# age                  4909
# hypertension         4909
# heart_disease        4909
# ever_married         4909
# work_type            4909
# Residence_type       4909
# avg_glucose_level    4909
# bmi                  4909
# smoking_status       4909
# stroke               4909
# dtype: int64

# %%
# Create the output file (CSV).
output_data_file = "resources/processed_stroke_db_w_cat.csv"
# Export the City_Data into a CSV.
df.to_csv(output_data_file)

# %%
# Change object dtypes to categorical
le = LabelEncoder()
categories = ["gender", "ever_married", "work_type", "Residence_type", "smoking_status"]

for category in categories:
    df[category] = le.fit_transform(df[category]) 


df
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# 5          1  81.0             0              0             1          2
# ...      ...   ...           ...            ...           ...        ...
# 5104       0  13.0             0              0             0          4
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# ...

# %%
# Double Check Data: Data types and null values
print(df.dtypes)

print(df.count())
# Out:
# gender                 int32
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married           int32
# work_type              int32
# Residence_type         int32
# avg_glucose_level    float64
# bmi                  float64
# smoking_status         int32
# stroke                 int64
# dtype: object
# gender               4909
# age                  4909
# hypertension         4909
# heart_disease        4909
# ever_married         4909
# work_type            4909
# Residence_type       4909
# avg_glucose_level    4909
# bmi                  4909
# smoking_status       4909
# stroke               4909
# dtype: int64

# %%
# Create the output file (CSV).
output_data_file = "resources/processed_stroke_db.csv"
# Export the City_Data into a CSV.
df.to_csv(output_data_file)
